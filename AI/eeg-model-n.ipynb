# %% [markdown]
# # Graduation Project – EEG Signal Classification using Deep Learning (Brain Pulse)
#
# **Academy:** Misr Engineering and Technology Academy (MET)
# **by:** Eng. Mohamed Elsayad
# **Date:** 1-7-2025

# %% [markdown]
# ## 🎓 Project Introduction
#
# Electroencephalography (EEG) is one of the most widely used techniques for recording brain activity. It plays a critical role in diagnosing neurological disorders such as **epilepsy, encephalopathy, and brain injuries**.
#
# However, interpreting EEG data requires expert neurologists and can be time-consuming, especially when analyzing long recordings. Therefore, **automated EEG classification** using machine learning and deep learning offers a promising solution.
#
# ---
#
# ### 🧪 Problem Statement
#
# The goal of this project is to **automatically classify EEG spectrograms** into six medical categories:
#
# - Seizure
# - LPD (Lateralized Periodic Discharges)
# - GPD (Generalized Periodic Discharges)
# - LRDA (Lateralized Rhythmic Delta Activity)
# - GRDA (Generalized Rhythmic Delta Activity)
# - Other
#
# This enables **faster diagnosis and supports clinical decision-making**.
#
# ---
#
# ### 📊 Dataset
#
# The dataset used is **"HMS - Harmful Brain Activity Classification"**, available on Kaggle. It contains thousands of EEG recordings represented as parquet files.
#
# ---
#
# ### 🎯 Project Objectives
#
# The primary goal of this project is to **support neurologists and healthcare professionals** by providing an automated tool that enables **faster and more accurate diagnosis** of abnormal brain activity through EEG analysis.
#
# To achieve this, the project will:
#
# - Load and preprocess EEG spectrogram data
# - Train a deep learning model (CNN) to classify EEG segments into medically relevant categories
# - Evaluate the model using clinical performance metrics such as accuracy, confusion matrix, and F1-score
# - Visualize model predictions to aid in clinical interpretation and decision-making
#
# ### 🌍 Why This Matters
#
# By building a reliable automated EEG classifier, this project contributes to the field of **AI-assisted healthcare**. It can assist neurologists, reduce diagnostic delays, and potentially be integrated into real-time EEG monitoring systems.

# %% [markdown]
# ### 📌 How EEG Works:
# - Electrodes are placed on the **scalp** using the international **10–20 system**.
# - These electrodes detect the electrical signals generated by **neuronal activity**, especially in the cerebral cortex.
# - The recorded signals are displayed as **waveforms**, showing how brain activity changes over time.
#
# ---
#
# ### 🧩 EEG Frequency Bands:
# EEG signals are typically analyzed based on frequency ranges known as **brain waves**:
#
# | Wave Type | Frequency (Hz) | Associated State |
# |-----------|----------------|------------------|
# | Delta     | 0.5 – 4        | Deep sleep       |
# | Theta     | 4 – 8          | Light sleep, drowsiness |
# | Alpha     | 8 – 13         | Relaxed wakefulness |
# | Beta      | 13 – 30        | Active thinking, concentration |
# | Gamma     | >30            | Cognitive processing, perception |
#
# ---
#
# ### ⚕️ Common Clinical Uses:
# - **Epilepsy detection** (especially seizures)
# - **Sleep studies** (polysomnography)
# - **Brain death confirmation**
# - **Monitoring anesthesia**
# - **Diagnosing brain disorders** (e.g., encephalopathy, tumors, strokes)
#
#
# ---
#
# > 🧠 EEG is a powerful window into the brain's real-time electrical activity — offering insights into both health and disease.

# %% [markdown]
# ## 🧠 EEG Signal Classes – Brief Description
#
# - **Seizure**
#   Seizures are abnormal bursts of electrical activity in the brain. They often indicate epilepsy or acute neurological events. Recognizing seizure patterns is critical for immediate diagnosis and treatment.
#
# - **LPD (Lateralized Periodic Discharges)**
#   LPDs are repetitive, periodic waveforms occurring on one side of the brain. They may be associated with acute brain injuries, such as strokes, infections, or tumors.
#
# - **GPD (Generalized Periodic Discharges)**
#   GPDs are periodic discharges that occur across both hemispheres. They are typically linked with diffuse brain dysfunction and may appear in metabolic encephalopathy or post-anoxic brain injury.
#
# - **LRDA (Lateralized Rhythmic Delta Activity)**
#   LRDA refers to rhythmic slow wave activity (delta range) occurring on one hemisphere. It may reflect structural brain abnormalities or evolving seizure activity.
#
# - **GRDA (Generalized Rhythmic Delta Activity)**
#   GRDA involves rhythmic delta activity distributed symmetrically across the brain. It can be seen in encephalopathy or during the recovery phase after a seizure.
#
# - **Other**
#   This class includes EEG segments that do not fit into the defined categories or represent normal/ambiguous activity. It helps reduce false positives and improves model robustness.

# %% [markdown]
# ## 🧠 What is the "Double Banana" Montage in EEG?
#
# The **"double banana"** is a common EEG montage (electrode arrangement) used to visualize brain activity. It is a **longitudinal bipolar montage**, meaning each channel represents the voltage difference between two electrodes placed **in a straight line along the anterior-posterior axis** of the head.
#
# - The term “banana” comes from the arc-shaped pattern of the electrodes on each hemisphere.
# - “Double” refers to having one arc on the left hemisphere and another on the right, forming two curved lines — hence "double banana".
#
# ### 📌 Key Features:
# - Helps in identifying lateralized abnormalities (e.g., seizures or slowing on one side of the brain).
# - Makes it easier to spot phase reversals, which indicate the location of maximum voltage change (useful in localizing seizure onset).
# - Standard montage used in clinical EEG recordings and educational materials.
#
# ### 🧩 Example Channels (Left Hemisphere):
# - Fp1 – F3
# - F3 – C3
# - C3 – P3
# - P3 – O1
#
# ### 🧩 Example Channels (Right Hemisphere):
# - Fp2 – F4
# - F4 – C4
# - C4 – P4
# - P4 – O2
#
# Each pair of electrodes forms one EEG channel showing the voltage difference between them over time.
#
# ---
#
# > 🧠 The "double banana" montage is helpful for both clinicians and algorithms to detect focal brain activity and abnormalities in a structured, interpretable way.

# %% [markdown]
# ## 📊 Spectrograms in EEG Analysis
#
# A **spectrogram** is a visual representation of the **frequency content of a signal over time**. In EEG analysis, spectrograms are widely used to transform raw brainwave signals into 2D images where:
#
# - The **x-axis** represents time
# - The **y-axis** represents frequency (in Hz)
# - The **color intensity** represents power (amplitude) at a specific frequency and time
#
# ---
#
# ### 🧠 Why Use Spectrograms for EEG?
#
# EEG signals are **non-stationary**, meaning their frequency content changes over time. By converting the signals into spectrograms, we can:
#
# - Capture temporal and spectral information simultaneously
# - Detect frequency-based patterns such as seizures, slowing, or rhythmic discharges
# - Enable the use of image-based deep learning models like CNNs
#
# ---
#
# ### 🧩 Brain Region Labels
#
# Each spectrogram corresponds to a recording from a specific **brain region or electrode group**, often labeled as:
#
# | Label | Region Description                     |
# |-------|----------------------------------------|
# | **LL** | Left Lateral – Left side, outer region of the brain |
# | **RL** | Right Lateral – Right side, outer region of the brain |
# | **LP** | Left Parasagittal – Left side, near the midline |
# | **RP** | Right Parasagittal – Right side, near the midline |
#
# These spatial labels help the model learn **location-based patterns** that might be indicative of specific neurological conditions.
#
# ---
#
# ### 🧪 Example: EEG Spectrogram as Input
#
# In this project, each 600-second EEG segment is converted into a **spectrogram array** (2D matrix), which serves as the input to a **deep learning model** for classification.
#
# This format is particularly effective for training **Convolutional Neural Networks (CNNs)**, as it allows the model to detect frequency-temporal patterns across various brain regions.

# %% [markdown]
# ## 📁 Step 1 – Load Dataset and Prepare Output Directory
#
# In this step, we import essential libraries, define file paths, and read the training metadata (`train.csv`) from the HMS EEG dataset.

# %%
# Import core libraries
import pandas as pd               # For handling CSV files and data manipulation
import numpy as np                # For numerical operations (used later)
import os                         # For general file operations
from pathlib import Path          # For handling file paths in a clean, OS-independent way
from tqdm.notebook import tqdm    # For displaying progress bars in notebooks

# Configuration
base_path = Path("/kaggle/input/hms-harmful-brain-activity-classification")  # Path to input dataset on Kaggle
output_path = Path("/kaggle/working/preprocessed_data")                      # Path to save any generated/preprocessed files
output_path.mkdir(exist_ok=True)  # Create output folder if it doesn't exist

# Load the metadata CSV file containing training labels and EEG segment info
df = pd.read_csv(base_path / "train.csv")

# Preview the first 5 rows to understand the structure
df.head(5)
# Out:
#        eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 0  1628180742           0                       0.0          353733
# 1  1628180742           1                       6.0          353733
# 2  1628180742           2                       8.0          353733
# 3  1628180742           3                      18.0          353733
# 4  1628180742           4                      24.0          353733
#
#    spectrogram_sub_id  spectrogram_label_offset_seconds    label_id  \
# 0                   0                               0.0   127492639
# 1                   1                               6.0  3887563113
# 2                   2                               8.0  1142670488
# 3                   3                              18.0  2718991173
# 4                   4                              24.0  3080632009
#
#    patient_id expert_consensus  seizure_vote  lpd_vote  gpd_vote  lrda_vote  \
# ...

# %% [markdown]
# ## 🧮 Step 2 – Calculate Start and End Rows for Spectrogram Slices
#
# Each sub-spectrogram in the dataset is 600 seconds long, and each row in the full spectrogram file represents 2 seconds.
# So, we divide the offset (in seconds) by 2 to get the `start_row`, and since each segment spans 600 seconds (which is 300 rows), we add 300 to get the `end_row`.

# %%
# Calculate the starting row in the full spectrogram file
# Each 2 seconds = 1 row ⇒ divide seconds by 2
df["start_row"] = df["spectrogram_label_offset_seconds"] / 2

# Each sub-spectrogram spans 600 seconds ⇒ 600 / 2 = 300 rows
# So the end row is start_row + 300
df["end_row"] = df["start_row"] + 300

# Display the updated DataFrame to confirm changes
df.head()
# Out:
#        eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 0  1628180742           0                       0.0          353733
# 1  1628180742           1                       6.0          353733
# 2  1628180742           2                       8.0          353733
# 3  1628180742           3                      18.0          353733
# 4  1628180742           4                      24.0          353733
#
#    spectrogram_sub_id  spectrogram_label_offset_seconds    label_id  \
# 0                   0                               0.0   127492639
# 1                   1                               6.0  3887563113
# 2                   2                               8.0  1142670488
# 3                   3                              18.0  2718991173
# 4                   4                              24.0  3080632009
#
#    patient_id expert_consensus  seizure_vote  lpd_vote  gpd_vote  lrda_vote  \
# ...

# %% [markdown]
# ## ✂️ Step 3 – Use a Subset of the Dataset for Faster Processing
#
# For faster experimentation or limited resource environments (like Kaggle kernels), we may choose to work on a smaller subset of the full dataset.
# Here, we select the first **25,082 samples** from the training DataFrame.

# %%
# Select the first 25,082 rows from the training data
# This helps reduce processing time and memory usage during development
half_data = df.head(25082)

# Reset the index of the subset 
half_data = half_data.reset_index(drop=True)

# Display the first few rows of the subset
half_data.head()
# Out:
#        eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 0  1628180742           0                       0.0          353733
# 1  1628180742           1                       6.0          353733
# 2  1628180742           2                       8.0          353733
# 3  1628180742           3                      18.0          353733
# 4  1628180742           4                      24.0          353733
#
#    spectrogram_sub_id  spectrogram_label_offset_seconds    label_id  \
# 0                   0                               0.0   127492639
# 1                   1                               6.0  3887563113
# 2                   2                               8.0  1142670488
# 3                   3                              18.0  2718991173
# 4                   4                              24.0  3080632009
#
#    patient_id expert_consensus  seizure_vote  lpd_vote  gpd_vote  lrda_vote  \
# ...

# %% [markdown]
# ## 🧪 Step 4 – Convert Spectrograms to NumPy Arrays (`.npy`)
#
# This loop processes each EEG segment by:
# - Loading the corresponding `.parquet` spectrogram file
# - Extracting the correct time window using `start_row` and `end_row`
# - Handling missing values
# - Saving the result as a `.npy` file for efficient model input
#
# This step speeds up training and avoids redundant computation during each epoch.

# %%
# Required libraries
import numpy as np
import os
from tqdm import tqdm

# === Step 4: Processing EEG Spectrograms ===
processed_df_list = []  # To store paths and labels for processed files

# Iterate through each row of the dataset with a progress bar
for _, row in tqdm(half_data.iterrows(), total=half_data.shape[0], desc="Processing Spectrograms"):
    
    # Extract spectrogram and label IDs
    spec_id = row['spectrogram_id']
    label_id = row['label_id']
    
    # Build file paths
    input_spec_path = base_path / "train_spectrograms" / f"{spec_id}.parquet"
    output_npy_path = output_path / f"{label_id}.npy"

    # Skip if already processed
    if not os.path.exists(output_npy_path):
        try:
            # Load the .parquet spectrogram file
            spectrogram = pd.read_parquet(input_spec_path)

            # Extract the slice corresponding to the sub-segment (600 seconds → 300 rows)
            start = int(row["start_row"])
            end = int(row["end_row"])
            spectrogram = spectrogram.iloc[start:end]

            # Fill any NaN values with column-wise means (prevents model failure)
            spectrogram = spectrogram.fillna(spectrogram.mean())

            # Drop the 'time' column and convert to NumPy array
            npy_data = spectrogram.drop('time', axis=1).to_numpy()

            # Save the array as .npy for faster loading during training
            np.save(output_npy_path, npy_data)

        except FileNotFoundError:
            print(f"Missing file for spectrogram_id: {spec_id}. Skipping.")
            continue

    # Append output path and label to list for later use
    processed_df_list.append({
        'npy_path': str(output_npy_path),
        'expert_consensus': row['expert_consensus']
    })

# Convert the list of dictionaries into a DataFrame for downstream use
processed_df = pd.DataFrame(processed_df_list)
print(f"\nCreated {len(processed_df)} .npy files.")
processed_df.head()
# Out:
# Processing Spectrograms: 100%|██████████| 25082/25082 [41:53<00:00,  9.98it/s]
# Created 25082 .npy files.
#                                            npy_path expert_consensus
# 0   /kaggle/working/preprocessed_data/127492639.npy          Seizure
# 1  /kaggle/working/preprocessed_data/3887563113.npy          Seizure
# 2  /kaggle/working/preprocessed_data/1142670488.npy          Seizure
# 3  /kaggle/working/preprocessed_data/2718991173.npy          Seizure
# 4  /kaggle/working/preprocessed_data/3080632009.npy          Seizure

# %% [markdown]
# ## 📊 Step 5 – Visualize Class Distribution
#
# Before training any model, it's important to check how balanced or imbalanced the target classes are.
# In this plot, we visualize the count of each `expert_consensus` label to understand the data distribution.

# %%
# Import visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Create a bar plot to show the number of samples per class
sns.countplot(x="expert_consensus", data=processed_df)

# Set axis labels and title
plt.xlabel("Classes")  # X-axis: class labels like Seizure, LPD, etc.
plt.ylabel("Counts")   # Y-axis: number of samples per class
plt.title("Distribution of expert_consensus")

# Rotate x-axis labels for better readability if long
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# ## 💻 Step 6 – Set Up PyTorch Device
#
# Before training the model, we check whether a **GPU (CUDA)** is available.
# If so, training will be performed on the GPU for better performance. Otherwise, it falls back to the CPU.

# %%
# Import PyTorch core and neural network modules
import torch
import torch.nn as nn

# Check if CUDA (GPU) is available; else fallback to CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Print the selected device (useful for debugging)
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ## 🧾 Step 7 – Encode Labels as Integers
#
# Most machine learning models require labels to be in numeric format.
# We use `LabelEncoder` to convert the `expert_consensus` labels (e.g., "seizure", "lpd") into integer class values.

# %%
from sklearn.preprocessing import LabelEncoder

# Create a label encoder instance
le = LabelEncoder()

# Fit the encoder on the expert_consensus labels and transform them into integers
processed_df["class"] = le.fit_transform(processed_df["expert_consensus"])

# Preview the DataFrame with the new numeric class column
processed_df.head()
# Out:
#                                            npy_path expert_consensus  class
# 0   /kaggle/working/preprocessed_data/127492639.npy          Seizure      5
# 1  /kaggle/working/preprocessed_data/3887563113.npy          Seizure      5
# 2  /kaggle/working/preprocessed_data/1142670488.npy          Seizure      5
# 3  /kaggle/working/preprocessed_data/2718991173.npy          Seizure      5
# 4  /kaggle/working/preprocessed_data/3080632009.npy          Seizure      5

# %% [markdown]
# ## 🧠 Label Mapping (Encoded Classes)
#
# | Class Name | Encoded Label |
# |------------|----------------|
# | GPD        | 0              |
# | GRDA       | 1              |
# | LPD        | 2              |
# | LRDA       | 3              |
# | Other      | 4              |
# | Seizure    | 5              |

# %% [markdown]
# ## 🧹 Step 8 – Drop Original Label Column
#
# Since we’ve already encoded `expert_consensus` into the `class` column,
# we can now drop the original text-based label to simplify the dataset.

# %%
# Drop the original label column (text) as it's no longer needed
processed_df.drop("expert_consensus", axis=1, inplace=True)

# Preview the updated DataFrame to confirm the change
processed_df.head()
# Out:
#                                            npy_path  class
# 0   /kaggle/working/preprocessed_data/127492639.npy      5
# 1  /kaggle/working/preprocessed_data/3887563113.npy      5
# 2  /kaggle/working/preprocessed_data/1142670488.npy      5
# 3  /kaggle/working/preprocessed_data/2718991173.npy      5
# 4  /kaggle/working/preprocessed_data/3080632009.npy      5

# %% [markdown]
# ## 📦 Step 9 – Create Custom Dataset Class for EEG Spectrograms
#
# This PyTorch `Dataset` class handles loading and preprocessing of spectrogram data.
# It ensures that each sample has a fixed shape, applies optional augmentation, and returns data-label pairs.

# %%
import torchvision.transforms as T
from torch.utils.data import Dataset, DataLoader

class SpectrogramDataset(Dataset):
    def __init__(self, df, augment=False):
        self.df = df
        self.augment = augment

        # Define simple torchvision-style augmentations (applied only if augment=True)
        self.transforms = T.Compose([
            T.RandomHorizontalFlip(p=0.5),
            T.RandomVerticalFlip(p=0.5),
            T.RandomAffine(degrees=10, translate=(0.1, 0.1), scale=(0.9, 1.1)),
        ])

    def __len__(self):
        # Return total number of samples
        return len(self.df)

    def __getitem__(self, idx):
        # Load .npy spectrogram file for the given index
        path = self.df.iloc[idx]["npy_path"]
        data = np.load(path)

        # Normalize: zero mean, unit variance
        data = (data - data.mean()) / (data.std() + 1e-8)

        # Ensure fixed shape: width = 400 columns (time), height = 300 rows (frequencies)
        if data.shape[1] < 400:
            pad_cols = 400 - data.shape[1]
            data = np.pad(data, ((0, 0), (0, pad_cols)), mode='constant')
        elif data.shape[1] > 400:
            data = data[:, :400]

        if data.shape[0] < 300:
            pad_rows = 300 - data.shape[0]
            data = np.pad(data, ((0, pad_rows), (0, 0)), mode='constant')
        elif data.shape[0] > 300:
            data = data[:300, :]

        # Reshape into 3D format: [channels, height, width]
        # Here: [4, 300, 100] by slicing into 4 equal vertical segments (simulating multi-channel input)
        try:
            data = data.reshape(300, 4, 100).transpose(1, 0, 2)  # shape: [4, 300, 100]
        except Exception as e:
            raise ValueError(f"❌ Error reshaping file {path} with shape {data.shape}: {e}")

        # Convert to PyTorch tensor
        data = torch.from_numpy(data).float()

        # Apply augmentation if enabled
        if self.augment:
            data = self.transforms(data)

        # Get label and convert to tensor
        label = torch.tensor(self.df.iloc[idx]["class"], dtype=torch.long)

        return data, label

# %% [markdown]
# ## 🔀 Step 10 – Split Data and Create PyTorch Dataloaders
#
# We split the preprocessed dataset into **training** and **validation** sets, preserving class balance using `stratify`.
# We then create `SpectrogramDataset` instances and wrap them in PyTorch `DataLoader`s for batch processing.

# %%
from sklearn.model_selection import train_test_split

# For reproducibility — ensures the same random split every run
torch.manual_seed(42)

# Split data into train and validation sets (80/20 split), keeping class distribution balanced
train_df, val_df = train_test_split(
    processed_df,
    test_size=0.2,
    random_state=42,
    stratify=processed_df['class']  # Ensures class distribution remains balanced in both sets
)

# Create dataset instances
# augment=False: no data augmentation applied here (you can enable later if needed)
train_dataset = SpectrogramDataset(train_df, augment=False)
val_dataset = SpectrogramDataset(val_df)

# Define batch size
BATCH_SIZE = 32

# Create DataLoaders for batch processing
# shuffle=True only for training (important for randomness)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)

# Print number of batches in each loader
print(f"The Train Data contains {len(train_loader)} batches and Validation Data contains {len(val_loader)} batches. Each batch contains {BATCH_SIZE} examples.")
# Out:
# the Train Data Contain 628 batches and Validation Data contain 157 , Each batch contain 32 Example.

# %% [markdown]
# ## 🧠 Step 11 – Define CNN Model for EEG Spectrogram Classification
#
# This Convolutional Neural Network (CNN) is designed to classify EEG spectrogram inputs into 6 medical categories.
# It takes an input of shape `(Batch, 4, 300, 100)` — representing 4 pseudo-channels of spectrogram data —
# and passes it through several convolutional blocks followed by fully connected layers.

# %%
import torch
import torch.nn as nn

class EEG_Spectrogram_CNN(nn.Module):
    def __init__(self, num_classes=6):
        super(EEG_Spectrogram_CNN, self).__init__()

        # === Convolutional Block 1 ===
        # Input: (Batch, 4, 300, 100)
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=4, out_channels=32, kernel_size=(5, 5), stride=1, padding=2),  # → (Batch, 32, 300, 100)
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=(2, 2), stride=2)  # → (Batch, 32, 150, 50)
        )

        # === Convolutional Block 2 ===
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=(3, 3), stride=1, padding=1),  # → (Batch, 64, 150, 50)
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=(2, 2), stride=2)  # → (Batch, 64, 75, 25)
        )

        # === Convolutional Block 3 ===
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=(3, 3), stride=1, padding=1),  # → (Batch, 128, 75, 25)
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=(3, 3), stride=3)  # → (Batch, 128, 25, 8)
        )

        # Flatten layer to prepare for fully connected classification head
        self.flatten = nn.Flatten()  # Output size: 128 × 25 × 8 = 25,600 features

        # === Fully Connected Classifier ===
        self.classifier = nn.Sequential(
            nn.Linear(128 * 25 * 8, 1024),
            nn.ReLU(),
            nn.Dropout(0.5),  # Dropout for regularization
            nn.Linear(1024, num_classes)  # Output: logits for 6 classes
        )

    def forward(self, x):
        # Forward pass through the network
        x = self.conv1(x)  # → (Batch, 32, 150, 50)
        x = self.conv2(x)  # → (Batch, 64, 75, 25)
        x = self.conv3(x)  # → (Batch, 128, 25, 8)
        x = self.flatten(x)
        logits = self.classifier(x)
        return logits

# %% [markdown]
# Let's break down the model's workflow step-by-step, from input to output.
#
# ### High-Level Overview
#
# The model takes a 4-channel array as input and processes it through several stages to produce 6 output values. This structure is typical for a classification problem with 6 possible categories. The architecture consists of two main parts:
# 1.  **Feature Extraction:** A series of Convolutional, ReLU, and Max Pooling layers that automatically learn and identify features (like edges, textures, and shapes) from the input image.
# 2.  **Classification:** A set of fully connected layers that take the extracted features and perform the final classification.
#
# ---
#
# ### Detailed Layer-by-Layer Explanation
#
# 1.  **Input (input.1)**
#     *   **Shape:** `1 × 4 × 300 × 100`
#     *   **What it is:** This is the input to the network. The dimensions represent:
#         *   `1`: Batch size (processing one array at a time) , it can be 16,32,64 or any number of batches.
#         *   `4`: Number of channels: LL = left lateral; RL = right lateral; LP = left parasagittal; RP = right parasagittal.
#         *   `300`: Height of the array.
#         *   `100`: Width of the array.
#
# 2.  **First Convolutional Block**
#     *   **Conv (Convolutional Layer):** This layer applies 32 different filters (or kernels) of size `5×5` to the input image. Each filter is designed to detect a specific low-level feature (e.g., a horizontal edge, a specific color gradient).
#         *   `W <32×4×5×5>`: These are the filter weights. 32 filters, each processing 4 input channels, with a spatial size of 5x5.
#         *   `B <32>`: A bias term is added to the output of each of the 32 filters.
#     *   **Relu (Rectified Linear Unit):** This is an activation function. It introduces non-linearity by changing all negative values in the feature maps to zero. This helps the model learn more complex patterns.
#     *   **MaxPool (Max Pooling):** This layer downsamples the feature maps, reducing their height and width. It does this by taking the maximum value from a small window as it slides across the map. This makes the model more efficient and robust to small variations in the position of features.
#
# 3.  **Second Convolutional Block**
#     *   **Conv:** The model now applies a deeper set of 64 filters, each with a `3×3` size, to the feature maps from the previous block. Smaller filters in deeper layers tend to combine the simpler features into more complex ones.
#         *   `W <64×32×3×3>`: 64 filters, processing the 32 feature maps from the previous block.
#         *   `B <64>`: 64 bias terms.
#     *   **Relu & MaxPool:** These perform the same functions as before, further processing and downsampling the 64 new feature maps.
#
# 4.  **Third Convolutional Block**
#     *   **Conv:** The complexity increases again. This layer uses 128 filters of size `3×3`.
#         *   `W <128×64×3×3>`: 128 filters, processing the 64 feature maps from the previous block.
#         *   `B <128>`: 128 bias terms.
#     *   **Relu & MaxPool:** The final activation and downsampling step in the feature extraction part. At this point, the model has produced 128 highly abstract feature maps of a much smaller spatial size than the original image.
#
# 5.  **Flatten Layer**
#     *   **What it does:** This layer takes the final 3D block of feature maps (e.g., shape `128 × height × width`) and unrolls it into a single, long 1D vector. This is necessary to transition from the convolutional part of the network to the fully connected classification part. The next layer's input size (`25600`) reveals the size of this flattened vector.
#
# 6.  **First Fully Connected Block**
#     *   **Gemm (General Matrix Multiplication):** This is a fully connected (or dense) layer. It performs a matrix multiplication to transform the 25,600-element feature vector into a 1,024-element vector. This layer learns to weigh the importance of different features for the classification task.
#         *   `B <1024×25600>`: The weight matrix.
#         *   `C <1024>`: The bias vector.
#     *   **Relu:** Another activation function is applied to the 1,024-element vector.
#
# 7.  **Second Fully Connected Block (Output Layer)**
#     *   **Gemm:** This is the final layer of the network. It takes the 1,024-element vector and transforms it into the final output vector of size 6.
#         *   `B <6×1024>`: The weight matrix that maps the 1,024 features to 6 output classes.
#         *   `C <6>`: The final bias vector for the 6 classes.
#
# 8.  **Output (Node 41)**
#     *   **Shape:** `1 × 6`
#     *   **What it is:** The model's final output is a vector of 6 numbers. In a classification context, each number represents a "score" or "logit" for one of the 6 possible classes. To get probabilities, these scores are typically passed through a Softmax function (which is not shown in this diagram). The class with the highest score (or probability) is the model's prediction.
#
# ### Summary of the Process
#
# The network progressively transforms a large, high-dimensional image into a small, 6-element vector. It starts by finding simple patterns, combines them into more complex features, and finally uses those features to make a decision about which of the 6 categories the original image belongs to.

# %% [markdown]
# ## 🔍 Step 12 – Initialize and Test the CNN Model
#
# Before training, we initialize the model and pass a dummy input to verify that:
# - The model structure is correct
# - The input/output dimensions match expectations

# %%
# Set seed to ensure reproducibility
torch.manual_seed(42)

# Initialize the model and move it to the GPU (or CPU if CUDA is not available)
model = EEG_Spectrogram_CNN().to(device)

# Create a dummy input with the same shape as actual data: [Batch, Channels, Height, Width]
dummy_input = torch.randn([1, 4, 300, 100]).to(device)

# Forward pass to ensure the model runs correctly
output = model(dummy_input)
print(output.shape)  # Should print: torch.Size([1, 6])
# Out:
# tensor([[-0.3060,  0.5963,  0.5941, -0.7290,  0.6303, -0.1152]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)

# %% [markdown]
# ## ⚙️ Step 13 – Define Loss Function and Optimizer
#
# We now set up the loss function and optimizer to train the CNN model:
#
# - `CrossEntropyLoss` is ideal for multi-class classification (e.g., 6 EEG classes)
# - `Adam` is a widely-used optimizer that combines the benefits of RMSProp and SGD with momentum

# %%
# Define the loss function
# CrossEntropyLoss expects raw logits and class labels (no softmax needed)
loss_fn = nn.CrossEntropyLoss()

# Define the optimizer
# Adam adjusts learning rates adaptively and usually converges faster
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %% [markdown]
# ## 🔁 Step 14 – Training and Evaluation Loop
#
# This loop trains the CNN for 12 epochs, evaluating on the validation set after each one.
#
# Key operations per epoch:
# - **Forward pass** to compute predictions
# - **Loss calculation** using CrossEntropyLoss
# - **Backward pass** (gradient computation)
# - **Optimizer step** (update weights)
# - **Validation** is done with `torch.no_grad()` to disable gradient tracking
#
# Intermediate progress is printed using `tqdm` and occasional batch updates.

# %%
from tqdm import tqdm

epochs = 12

for epoch in tqdm(range(epochs)):
    # === Training Phase ===
    model.train()
    train_loss = 0.0
    train_accuracy = 0.0

    for batch, (x, y) in enumerate(train_loader):
        x = x.to(device)
        y = y.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        y_pred = model(x)

        # Compute loss
        loss = loss_fn(y_pred, y)

        # Backward pass (compute gradients)
        loss.backward()

        # Update model parameters
        optimizer.step()

        # Accumulate loss and accuracy
        train_loss += loss.item()
        correct = (y_pred.argmax(dim=1) == y).sum().item()
        train_accuracy += correct / y.size(0)

        # Optional progress print every ~5000 samples
        if batch % 157 == 0:
            print(f"{batch * BATCH_SIZE} from {len(train_loader) * BATCH_SIZE}")

    # Average metrics over all batches
    train_loss /= len(train_loader)
    train_accuracy /= len(train_loader)

    print(f"[Epoch {epoch+1}/{epochs}] Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}")

    # === Validation Phase ===
    model.eval()
    val_loss = 0.0
    val_accuracy = 0.0

    with torch.no_grad():  # Disable gradient tracking for validation
        for batch, (x, y) in enumerate(val_loader):
            x = x.to(device)
            y = y.to(device)

            # Forward pass
            y_pred = model(x)
            loss = loss_fn(y_pred, y)

            # Accumulate loss and accuracy
            val_loss += loss.item()
            correct = (y_pred.argmax(dim=1) == y).sum().item()
            val_accuracy += correct / y.size(0)

            # Optional progress print
            if batch % 25 == 0:
                print(f"{batch * BATCH_SIZE} from {len(val_loader) * BATCH_SIZE}")

    # Average validation metrics
    val_loss /= len(val_loader)
    val_accuracy /= len(val_loader)

    print(f"         >> Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}")
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# 0 from 20096
# 5024 from 20096
# 10048 from 20096
# 15072 from 20096
# [Epoch 1/12] Train Loss: 1.4612, Train Accuracy: 0.4165
# 0 from 5024
# 800 from 5024
# 1600 from 5024
# 2400 from 5024
# 3200 from 5024
# 4000 from 5024
# 4800 from 5024
#   8%|▊         | 1/12 [01:27<16:01, 87.39s/it]
#          >> Validation Loss: 1.2609, Validation Accuracy: 0.5051
# 0 from 20096
# 5024 from 20096
# 10048 from 20096
# 15072 from 20096
# [Epoch 2/12] Train Loss: 1.2090, Train Accuracy: 0.5279
# 0 from 5024
# 800 from 5024
# 1600 from 5024
# 2400 from 5024
# 3200 from 5024
# 4000 from 5024
# 4800 from 5024
#  17%|█▋        | 2/12 [02:51<14:14, 85.43s/it]
#          >> Validation Loss: 1.0336, Validation Accuracy: 0.6138
# 0 from 20096
# 5024 from 20096
# 10048 from 20096
# 15072 from 20096
# [Epoch 3/12] Train Loss: 1.0391, Train Accuracy: 0.6025
# 0 from 5024
# 800 from 5024
# 1600 from 5024
# 2400 from 5024
# 3200 from 5024
# 4000 from 5024
# ...

# %% [markdown]
# ## 📊 Step 15 – Confusion Matrix Visualization
#
# After training, it's important to assess the model’s **per-class performance**.
# The **confusion matrix** shows how often each class was correctly predicted or confused with another class.
#
# In this case:
# - We normalize by row (`normalize='true'`) to see **percentages relative to true labels**
# - The matrix uses the original class names (e.g., "GPD", "Seizure") from `LabelEncoder`
#
# This helps identify which classes are most frequently misclassified.

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# === Step 1: Collect true and predicted labels ===
# Make sure your model is in evaluation mode and not tracking gradients
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for x, y in val_loader:
        x = x.to(device)
        y = y.to(device)

        outputs = model(x)
        preds = torch.argmax(outputs, dim=1)

        # Store predictions and true labels
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(y.cpu().numpy())

# === Step 2: Plot Normalized Confusion Matrix (as % per true class) ===
ConfusionMatrixDisplay.from_predictions(
    y_true=all_labels,
    y_pred=all_preds,
    normalize='true',              # Normalize by true labels (row-wise)
    values_format='.0%',           # Display values as whole number percentages
    display_labels=le.classes_     # Use the original class names from LabelEncoder
)

# === Step 3: Plot Formatting ===
plt.title("Normalized Confusion Matrix (%)")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ❌ Step 16 – Confusion Matrix for Misclassifications Only
#
# To focus purely on the **model's mistakes**, we compute a confusion matrix where:
#
# - Each correctly predicted sample has weight 0
# - Each incorrect sample has weight 1 (`sample_weight`)
#
# This reveals **only where and how often the model makes errors**, helping us identify problematic class pairs.

# %%
all_labels = np.array(all_labels)
all_preds = np.array(all_preds)

# Highlight errors only
sample_weight = (all_labels != all_preds).astype(int)

# Plot confusion matrix using errors only
ConfusionMatrixDisplay.from_predictions(
    y_true=all_labels,
    y_pred=all_preds,
    sample_weight=sample_weight,
    normalize='true',
    values_format='.0%',
    display_labels=le.classes_
)

plt.title("Confusion Matrix (Misclassifications Only, %)")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🧪 Step 17 – Inference on a Single Test Spectrogram
#
# We now load a `.parquet` spectrogram file from the test set, preprocess it exactly as during training, and pass it through the trained model to get a prediction.
#
# Steps:
# 1. Load and normalize the EEG spectrogram
# 2. Reshape into CNN-compatible format: `(4, 300, 100)`
# 3. Convert to PyTorch tensor and add batch dimension
# 4. Get predicted class from model output

# %%
# === Load and preprocess test sample ===
test_df = pd.read_parquet("/kaggle/input/hms-harmful-brain-activity-classification/test_spectrograms/853520.parquet")

# Drop the 'time' column and convert to NumPy array
test_array = np.array(test_df.iloc[:, 1:])

# Normalize (zero mean, unit variance)
test_array = (test_array - test_array.mean()) / (test_array.std() + 1e-8)

# Reshape to match model input: (4, 300, 100)
test_array = test_array.reshape(300, 4, 100).transpose(1, 0, 2)

# Convert to torch tensor and move to device
test_tensor = torch.tensor(test_array, dtype=torch.float).to(device)

# Add batch dimension: shape becomes (1, 4, 300, 100)
test_tensor = test_tensor.unsqueeze(0)

# === Inference ===
model.eval()  # Ensure model is in evaluation mode
y_test_logit = model(test_tensor)
y_test_probs = torch.softmax(y_test_logit, dim=1)
predicted_class = torch.argmax(y_test_probs, dim=1)

# Display the predicted class index
predicted_class
# Out:
# tensor([4], device='cuda:0')

# %% [markdown]
# We ran inference on a real test spectrogram:
# **`853520.parquet`** from the test set.
#
# 📌 **Prediction Result:**
# - 🔢 Predicted Class Index: `4`
# - 🏷️ Predicted Label: **Other**
# - ✅ This prediction is **correct** based on the ground truth.
#
# This demonstrates the model's ability to generalize to unseen EEG segments and correctly identify non-pathological or undefined brain activity labeled as **"Other"**.

# %% [markdown]
# ## 💾 Step 19 – Save the Trained Model
#
# To reuse the trained model later (for inference or further training), we save:
#
# - The **entire model** (`EEGModel.pth`): structure + weights
# - The **model weights only** (`EEGModelw.pth`): for use with same model class

# %%
# Save the full model (architecture + parameters)
torch.save(model, "EEGModel.pth")

# Save only the model weights (recommended for deployment)
torch.save(model.state_dict(), "EEGModelw.pth")

# %% [markdown]
# ---
#
# ## 🏁 Final Remarks
#
# This notebook presented a complete deep learning pipeline for classifying EEG spectrograms using a Convolutional Neural Network (CNN).
# We covered:
#
# - Data loading and preprocessing
# - Custom dataset creation
# - Model architecture definition
# - Training and validation with performance monitoring
# - Inference on new data and saving the model
#
# The model achieved promising results and demonstrated its ability to assist in identifying EEG patterns related to neurological activity.
# With further tuning, data balancing, or architecture enhancements, performance can be pushed even further.
#
# ---
#
# ## 🙏 Thanks for Reading!
#
# This project was developed as part of the **Graduation Project** at
# **Misr Engineering and Technology Academy (MET)**
# by **Eng. Mohamed Elsayad**.
#
# Feel free to reach out on [LinkedIn](https://www.linkedin.com/in/mohamed-elsayad-800a66291/) or GitHub if you have questions or would like to collaborate.
#
# 🧠🚀
